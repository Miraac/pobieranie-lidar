# %% [markdown]
# # Wysłanie współrzędnych i otrzymanie adresu

# %%
import geopandas as gpd
import requests
from shapely.geometry import Point, LineString, Polygon
import os
import rasterio
import numpy as np
import pandas as pd
from rasterio.mask import mask
from pathlib import Path

# %% [markdown]
# # Pozyskiwanie adresów przez API (pominąć)
# Z uwagi na ograniczenia w pozyskiwaniu danych w ten sposób porzucono wykorzystywanie API na rzecz gotowych skorowidzów. Kod w tej sekcji jest jedynie do demonstracji.

# %%
def points_from_vector_layer(path_to_vector,density=250,target_crs="EPSG:2180"):
    """
    Generuje punkty zapytań (shapely Point) na podstawie warstwy wektorowej
    """
    gdf = gpd.read_file(path_to_vector)

    if gdf.crs is None or gdf.crs.to_string() != target_crs:
        gdf = gdf.to_crs(target_crs)

    points = []

    for geom in gdf.geometry:
        if geom is None or geom.is_empty:
            continue
        if geom.geom_type == "Point":
            points.append(geom)
        elif geom.geom_type in ["LineString", "MultiLineString"]:
            lines = [geom] if geom.geom_type == "LineString" else geom.geoms

            for line in lines:
                length = line.length
                n = max(int(length / density), 1)

                for i in range(n + 1):
                    point = line.interpolate(i / n, normalized=True)
                    points.append(point)

        if geom.geom_type in ["Polygon", "MultiPolygon"]:
            polygon = geom if geom.geom_type == "Polygon" else unary_union(geom)

            cx, cy = polygon.centroid.coords[0]
            minx, miny, maxx, maxy = polygon.bounds

            x_coords = np.arange(cx, maxx + density, density)
            x_coords = np.concatenate([x_coords, np.arange(cx - density, minx - density, -density)])

            y_coords = np.arange(cy, maxy + density, density)
            y_coords = np.concatenate([y_coords, np.arange(cy - density, miny - density, -density)])

            for x in x_coords:
                for y in y_coords:
                    p = Point(x, y)
                    if polygon.covers(p):
                        points.append(p)

    return points

# %%
import requests
import datetime
import re
from shapely.geometry import Point
from typing import List, Dict, Any
from urllib3.exceptions import InsecureRequestWarning
import warnings
import time

warnings.filterwarnings("ignore", category=InsecureRequestWarning)
LAS_EVRF_WMS_URL = "https://opendata.geoportal.gov.pl/NumDaneWys/WMS/LAS_EVRF_WMS"

expr = re.compile(r"\{.*?\}")

def get_feature_info(params, url, retries=3, timeout=20, sleep_s=0.3):
    for attempt in range(retries):
        try:
            r = requests.get(url, params=params, verify=False, timeout=timeout)
            r.raise_for_status()
            return r.text
        except requests.exceptions.ReadTimeout:
            print('wewnetrzny timeout')
            if attempt == retries - 1:
                raise
            time.sleep(sleep_s)
    r = requests.get(url, params=params, verify=False, timeout=20)
    r.raise_for_status()
    return r.text

def remove_duplicates_from_list_of_dicts(dict_list):
    seen = set()
    unique_dict_list = []
    for d in dict_list:
        fset = frozenset(d.items())
        if fset not in seen:
            seen.add(fset)
            unique_dict_list.append(d)
    return unique_dict_list

# Wersja z opóźniaczem
def getLasListbyPoint1992(point, LAS_EVRF_WMS_URL):
    x, y = point.x, point.y
    layers = ['SkorowidzeLIDAR2022iStarsze', 'SkorowidzeLIDAR2023', 'SkorowidzeLIDAR2024', 'SkorowidzeLIDAR2025']

    params = {
        'SERVICE': 'WMS',
        'REQUEST': 'GetFeatureInfo',
        'VERSION': '1.3.0',
        'LAYERS': ','.join(layers),
        'QUERY_LAYERS': ','.join(layers),
        'CRS': 'EPSG:2180',
        'BBOX': f'{y-50},{x-50},{y+50},{x+50}',
        'WIDTH': 101,
        'HEIGHT': 101,
        'I': 50,
        'J': 50,
        'INFO_FORMAT': 'text/html',
        'FORMAT': 'image/png'
    }

    html = get_feature_info(params, LAS_EVRF_WMS_URL)

    # parsowanie HTML -> lista kafli
    elems = expr.findall(html)
    sub_list = []
    for e in elems:
        attrs = {}
        parts = e.strip("{}").split(',')
        for p in parts:
            k, v = p.split(':', 1)
            attrs[k.strip('" ')] = v.strip('" ')
        sub_list.append(attrs)

    # konwersja typów na float/int/date tak jak w wtyczce
    for elem in sub_list:
        if 'aktualnosc' in elem:
            elem['aktualnosc'] = datetime.datetime.strptime(elem['aktualnosc'], '%Y-%m-%d').date()
        for key in ['charakterystykaPrzestrzenna', 'bladSredniWysokosci', 'bladSredniPolozenia']:
            if key in elem:
                elem[key] = float(elem[key].split()[0]) if key=='charakterystykaPrzestrzenna' else float(elem[key])
        if 'aktualnoscRok' in elem:
            elem['aktualnoscRok'] = int(elem['aktualnoscRok'])

    return remove_duplicates_from_list_of_dicts(sub_list)

# %%
# Wersja bez opóźniacza
def getLasListbyPoint1992(point):
    x, y = point.x, point.y
    layers = ['SkorowidzeLIDAR2022iStarsze', 'SkorowidzeLIDAR2023', 
              'SkorowidzeLIDAR2024', 'SkorowidzeLIDAR2025']

    params = {
        'SERVICE': 'WMS',
        'REQUEST': 'GetFeatureInfo',
        'VERSION': '1.3.0',
        'LAYERS': ','.join(layers),
        'QUERY_LAYERS': ','.join(layers),
        'CRS': 'EPSG:2180',
        'BBOX': f'{y-50},{x-50},{y+50},{x+50}',
        'WIDTH': 101,
        'HEIGHT': 101,
        'I': 50,
        'J': 50,
        'INFO_FORMAT': 'text/html',
        'FORMAT': 'image/png'
    }

    resp = requests.get(params=params, verify=False, timeout=20)
    resp.raise_for_status()
    html = resp.text

    # parsowanie HTML -> lista kafli
    elems = expr.findall(html)
    sub_list = []
    for e in elems:
        attrs = {}
        parts = e.strip("{}").split(',')
        for p in parts:
            k, v = p.split(':', 1)
            attrs[k.strip('" ')] = v.strip('" ')
        sub_list.append(attrs)

    # konwersja typów na float/int/date tak jak w wtyczce
    for elem in sub_list:
        if 'aktualnosc' in elem:
            elem['aktualnosc'] = datetime.datetime.strptime(elem['aktualnosc'], '%Y-%m-%d').date()
        for key in ['charakterystykaPrzestrzenna', 'bladSredniWysokosci', 'bladSredniPolozenia']:
            if key in elem:
                elem[key] = float(elem[key].split()[0]) if key=='charakterystykaPrzestrzenna' else float(elem[key])
        if 'aktualnoscRok' in elem:
            elem['aktualnoscRok'] = int(elem['aktualnoscRok'])

    return remove_duplicates_from_list_of_dicts(sub_list)

# %% [markdown]
# # Odczytywanie adresów z lokalnie pobranych skorowidzów

# %%
# pozyskanie danych na skorowidze
def import_skorowidze(folder, target_crs="EPSG:2180"):
    gdfs = []

    for gml_path in Path(folder).glob("*.gml"):
        gdf = gpd.read_file(gml_path)

        # CRS
        if gdf.crs is None or gdf.crs.to_string() != target_crs:
            gdf = gdf.to_crs(target_crs)

        # standaryzacja nazw kolumn (na wszelki wypadek)
        rename_map = {
            "godlo": "godlo",
            "akt_rok": "akt_rok",
            "url_do_pobrania": "url"
        }

        gdf = gdf.rename(columns=rename_map)

        # zostawiamy tylko to co potrzebne
        gdf = gdf[["godlo", "akt_rok", "url", "geometry"]]


        gdfs.append(gdf)

    if not gdfs:
        raise ValueError("Nie znaleziono żadnych plików GML w folderze")

    out_gdf = gpd.GeoDataFrame(
        pd.concat(gdfs, ignore_index=True),
        crs=target_crs
    )
    out_gdf["filename"] = out_gdf["url"].apply(lambda u: u.split("/")[-1])

    return out_gdf
    
def filtruj_najnowsze(dane):
    dane = dane.sort_values("akt_rok", ascending=False).drop_duplicates(subset="godlo", keep="first").reset_index(drop=True)
    return dane

# usuwanie rekordów poza powierzchniami
def filtruj_po_polishp(skorowidze, shp):
    if skorowidze.crs != shp.crs:
        shp = shp.to_crs(skorowidze.crs)
    aoi_union = shp.geometry.union_all()

    mask = skorowidze.geometry.intersects(aoi_union)

    return skorowidze[mask].reset_index(drop=True)

# %% [markdown]
# # Sam mechanizm pobrania kafla na podstawie adresu

# %%
def pobierz_kafla(las_url, file_path):
    # wyciągamy nazwę pliku z URL
    file_name = las_url.split('/')[-1]
    file_path = os.path.join(file_path, file_name)

    #print(f"Pobieram {las_url} ...")
    try:
        with requests.get(las_url, stream=True) as r:
            r.raise_for_status()
            with open(file_path, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
        #print(f"Pobrano plik do: {file_path}")
    except requests.exceptions.HTTPError as e:
        print(f"Błąd HTTP: {e}")
    except requests.exceptions.ConnectionError:
        print("Błąd połączenia")
    except Exception as e:
        print(f"Nieoczekiwany błąd: {e}")

# %%
# możliwe, że na ten moment to zbędne
def unique_las_items(items):
    by_godlo = {}

    for item in items:
        godlo = item.get('godlo')
        rok = item.get('aktualnoscRok', -1)

        if godlo not in by_godlo or rok > by_godlo[godlo].get('aktualnoscRok', -1):
            by_godlo[godlo] = item

    # dodatkowo usuwamy duplikaty po URL (na wypadek błędnych danych)
    seen_urls = set()
    out = []

    for item in by_godlo.values():
        url = item.get('url')
        if url not in seen_urls:
            seen_urls.add(url)
            out.append(item)

    return out

# %% [markdown]
# # <font color="orange">Proces</font>
# Uruchamianie utworzonych funkcji i rozpoczynanie procesu pobierania danych. Przed uruchomieniem procesu wprowadzić poprawne ścieżki dla plików

# %%
# zmienne
output_path = 'ścieżka dla danych wyjściowych'
shp_path = 'ścieżka dla pliku shp + nazwa pliku .shp'
skorowidze_path =  'Scieżka folderu ze skorowidzami'

# %% [markdown]
# ## Pobranie skoroszytów

# %%
s_dane = import_skorowidze(skorowidze_path)
s_dane = filtruj_najnowsze(s_dane)
len(s_dane)
# Out:
# 40586

# %%
# sprawdzenie położenia kafli wykonując warstwę shp
s_dane.to_file(r'D:\Studia Big Data\DYPLOMOWA\shp\kafle_kluczbork.shp')

# %%
# filtrowanie po terenach leśnych
shp = gpd.read_file(shp_path)
s_dane = filtruj_po_polishp(s_dane, shp)
len(s_dane)
# Out:
# 333

# %%
def zredukuj_pobrane(download_dir):
    download_dir = Path(download_dir)
    pobrane_pliki = {p.name for p in download_dir.glob("*.laz")}
    do_pobrania = s_dane[~s_dane["filename"].isin(pobrane_pliki)].copy()
    return do_pobrania

# %%
# usuwanie z listy pobrane kafle jeśli proces został przerwany w trakcie
s_dane = zredukuj_pobrane(output_path)

# %% [markdown]
# ## Pobranie kafli

# %%
from tqdm import tqdm
import time
for _, r in tqdm(s_dane.iterrows(), total=len(s_dane), desc="Pobieranie..."):
    pobierz_kafla(r["url"], output_path)

# %% [markdown]
# # <font color="orange">Mechanizm importowania plików NMT</font>
# Pobieranie kafli nmt z Geoportalu w formacie .asc

# %%
skoroszyt_nmt = r'ścieżka dla skoroszytów + nazwa danego skoroszytu .gml'
output_nmt = r'ścieżka zapisu nmt'

# %%
def read_skorowidz_nmt(gml_path, target_crs="EPSG:2180"):
    gdf = gpd.read_file(gml_path)

    # CRS (na wszelki wypadek)
    if gdf.crs is None:
        gdf = gdf.set_crs(target_crs)
    elif gdf.crs.to_string() != target_crs:
        gdf = gdf.to_crs(target_crs)

    cols = [
        "godlo",
        "url_do_pobrania",
        "format",
        "char_przestrz",
        "akt_rok",
        "geometry",
    ]

    return gdf[cols]

# %%
def pobierz_nmt_asc(url, out_dir, overwrite=False, timeout=60):
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)
    file_name = url.split("/")[-1]
    out_path = out_dir / file_name

    if out_path.exists() and not overwrite:
        print(f"✔️ Już istnieje: {out_path.name}")
        return out_path

    print(f"⬇️ Pobieram: {file_name}")

    try:
        with requests.get(url, stream=True, timeout=timeout) as r:
            r.raise_for_status()

            with open(out_path, "wb") as f:
                for chunk in r.iter_content(chunk_size=1024 * 1024):
                    if chunk:
                        f.write(chunk)

        print(f"✅ Pobrano: {out_path}")
        return out_path

    except requests.exceptions.RequestException as e:
        print(f"❌ Błąd pobierania {url}\n{e}")
        return None

# %%
# zmienne 
shp_rdlp_path = r'ścieżka dla pliku + nazwa pliku .shp'

# %%
shp_rdlp = gpd.read_file(shp_rdlp_path)
dane_nmt = filtruj_po_polishp(dane_nmt, shp_rdlp)

# %%
for i, layer in dane_nmt.iterrows():
    pobierz_nmt_asc(layer['url_do_pobrania'], output_nmt)
# Out:
# ⬇️ Pobieram: 77532_1356600_M-34-52-D-c-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356600_M-34-52-D-c-1-1.asc
# ⬇️ Pobieram: 77532_1356613_M-34-52-D-c-4-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356613_M-34-52-D-c-4-2.asc
# ⬇️ Pobieram: 77532_1356612_M-34-52-D-c-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356612_M-34-52-D-c-4-1.asc
# ⬇️ Pobieram: 77532_1356572_M-34-52-C-b-4-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356572_M-34-52-C-b-4-4.asc
# ⬇️ Pobieram: 77532_1356577_M-34-52-C-c-3-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356577_M-34-52-C-c-3-1.asc
# ⬇️ Pobieram: 77532_1356578_M-34-52-C-c-3-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356578_M-34-52-C-c-3-2.asc
# ⬇️ Pobieram: 77532_1356610_M-34-52-D-c-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356610_M-34-52-D-c-3-3.asc
# ⬇️ Pobieram: 77532_1356595_M-34-52-C-d-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356595_M-34-52-C-d-4-1.asc
# ⬇️ Pobieram: 77532_1356585_M-34-52-C-d-1-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356585_M-34-52-C-d-1-3.asc
# ⬇️ Pobieram: 77532_1356608_M-34-52-D-c-3-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356608_M-34-52-D-c-3-1.asc
# ⬇️ Pobieram: 77532_1356593_M-34-52-C-d-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356593_M-34-52-C-d-3-3.asc
# ⬇️ Pobieram: 77532_1356611_M-34-52-D-c-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356611_M-34-52-D-c-3-4.asc
# ⬇️ Pobieram: 77532_1356579_M-34-52-C-c-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356579_M-34-52-C-c-3-3.asc
# ⬇️ Pobieram: 77532_1356598_M-34-52-C-d-4-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356598_M-34-52-C-d-4-4.asc
# ⬇️ Pobieram: 77532_1356587_M-34-52-C-d-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356587_M-34-52-C-d-2-1.asc
# ⬇️ Pobieram: 77532_1356584_M-34-52-C-c-4-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356584_M-34-52-C-c-4-4.asc
# ⬇️ Pobieram: 77532_1356609_M-34-52-D-c-3-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356609_M-34-52-D-c-3-2.asc
# ⬇️ Pobieram: 77532_1356603_M-34-52-D-c-1-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356603_M-34-52-D-c-1-4.asc
# ⬇️ Pobieram: 77532_1356599_M-34-52-D-a-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356599_M-34-52-D-a-3-3.asc
# ⬇️ Pobieram: 77532_1356590_M-34-52-C-d-2-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356590_M-34-52-C-d-2-4.asc
# ⬇️ Pobieram: 77532_1356583_M-34-52-C-c-4-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356583_M-34-52-C-c-4-3.asc
# ⬇️ Pobieram: 77532_1356586_M-34-52-C-d-1-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356586_M-34-52-C-d-1-4.asc
# ⬇️ Pobieram: 77532_1356592_M-34-52-C-d-3-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356592_M-34-52-C-d-3-2.asc
# ⬇️ Pobieram: 77532_1356607_M-34-52-D-c-2-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356607_M-34-52-D-c-2-4.asc
# ⬇️ Pobieram: 77532_1356602_M-34-52-D-c-1-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356602_M-34-52-D-c-1-3.asc
# ⬇️ Pobieram: 77532_1356580_M-34-52-C-c-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356580_M-34-52-C-c-3-4.asc
# ⬇️ Pobieram: 77532_1356588_M-34-52-C-d-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356588_M-34-52-C-d-2-2.asc
# ⬇️ Pobieram: 77532_1356581_M-34-52-C-c-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356581_M-34-52-C-c-4-1.asc
# ⬇️ Pobieram: 77532_1356616_M-34-52-D-d-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356616_M-34-52-D-d-1-1.asc
# ⬇️ Pobieram: 77532_1356606_M-34-52-D-c-2-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356606_M-34-52-D-c-2-3.asc
# ⬇️ Pobieram: 77532_1356573_M-34-52-C-c-1-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356573_M-34-52-C-c-1-3.asc
# ⬇️ Pobieram: 77532_1356597_M-34-52-C-d-4-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356597_M-34-52-C-d-4-3.asc
# ⬇️ Pobieram: 77532_1356589_M-34-52-C-d-2-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356589_M-34-52-C-d-2-3.asc
# ⬇️ Pobieram: 77532_1356576_M-34-52-C-c-2-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356576_M-34-52-C-c-2-4.asc
# ⬇️ Pobieram: 77532_1356605_M-34-52-D-c-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356605_M-34-52-D-c-2-2.asc
# ⬇️ Pobieram: 77532_1356601_M-34-52-D-c-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356601_M-34-52-D-c-1-2.asc
# ⬇️ Pobieram: 77532_1356604_M-34-52-D-c-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356604_M-34-52-D-c-2-1.asc
# ⬇️ Pobieram: 77532_1356596_M-34-52-C-d-4-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356596_M-34-52-C-d-4-2.asc
# ⬇️ Pobieram: 77532_1356591_M-34-52-C-d-3-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356591_M-34-52-C-d-3-1.asc
# ⬇️ Pobieram: 77532_1356582_M-34-52-C-c-4-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356582_M-34-52-C-c-4-2.asc
# ⬇️ Pobieram: 77532_1356594_M-34-52-C-d-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356594_M-34-52-C-d-3-4.asc
# ⬇️ Pobieram: 77532_1356574_M-34-52-C-c-1-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356574_M-34-52-C-c-1-4.asc
# ⬇️ Pobieram: 77532_1356614_M-34-52-D-c-4-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356614_M-34-52-D-c-4-3.asc
# ⬇️ Pobieram: 77532_1356575_M-34-52-C-c-2-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356575_M-34-52-C-c-2-3.asc
# ⬇️ Pobieram: 77532_1356631_M-34-63-B-b-3-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356631_M-34-63-B-b-3-2.asc
# ⬇️ Pobieram: 77532_1356661_M-34-64-A-b-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356661_M-34-64-A-b-3-3.asc
# ⬇️ Pobieram: 77532_1356632_M-34-63-B-b-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356632_M-34-63-B-b-3-4.asc
# ⬇️ Pobieram: 77532_1356563_M-34-64-C-a-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356563_M-34-64-C-a-2-1.asc
# ⬇️ Pobieram: 77532_1356678_M-34-64-A-c-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356678_M-34-64-A-c-3-4.asc
# ⬇️ Pobieram: 77532_1356651_M-34-64-A-b-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356651_M-34-64-A-b-1-1.asc
# ⬇️ Pobieram: 77532_1356645_M-34-63-B-d-4-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356645_M-34-63-B-d-4-4.asc
# ⬇️ Pobieram: 77532_1356692_M-34-64-A-d-3-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356692_M-34-64-A-d-3-2.asc
# ⬇️ Pobieram: 77532_1356337_M-34-64-C-a-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356337_M-34-64-C-a-1-1.asc
# ⬇️ Pobieram: 77532_1356633_M-34-63-B-b-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356633_M-34-63-B-b-4-1.asc
# ⬇️ Pobieram: 77532_1356560_M-34-64-C-a-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356560_M-34-64-C-a-1-2.asc
# ⬇️ Pobieram: 77532_1356687_M-34-64-A-d-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356687_M-34-64-A-d-2-1.asc
# ⬇️ Pobieram: 77532_1356668_M-34-64-A-c-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356668_M-34-64-A-c-1-2.asc
# ⬇️ Pobieram: 77532_1356652_M-34-64-A-b-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356652_M-34-64-A-b-1-2.asc
# ⬇️ Pobieram: 77532_1356676_M-34-64-A-c-3-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356676_M-34-64-A-c-3-2.asc
# ⬇️ Pobieram: 77532_1356681_M-34-64-A-c-4-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356681_M-34-64-A-c-4-3.asc
# ⬇️ Pobieram: 77532_1356689_M-34-64-A-d-2-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356689_M-34-64-A-d-2-3.asc
# ⬇️ Pobieram: 77532_1356662_M-34-64-A-b-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356662_M-34-64-A-b-3-4.asc
# ⬇️ Pobieram: 77532_1356637_M-34-63-B-d-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356637_M-34-63-B-d-2-1.asc
# ⬇️ Pobieram: 77532_1356667_M-34-64-A-c-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356667_M-34-64-A-c-1-1.asc
# ⬇️ Pobieram: 77532_1356702_M-34-64-B-a-1-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356702_M-34-64-B-a-1-4.asc
# ⬇️ Pobieram: 77532_1356644_M-34-63-B-d-4-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356644_M-34-63-B-d-4-3.asc
# ⬇️ Pobieram: 77532_1356680_M-34-64-A-c-4-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356680_M-34-64-A-c-4-2.asc
# ⬇️ Pobieram: 77532_1356669_M-34-64-A-c-1-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356669_M-34-64-A-c-1-3.asc
# ⬇️ Pobieram: 77532_1356665_M-34-64-A-b-4-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356665_M-34-64-A-b-4-3.asc
# ⬇️ Pobieram: 77532_1356699_M-34-64-B-a-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356699_M-34-64-B-a-1-1.asc
# ⬇️ Pobieram: 77532_1356636_M-34-63-B-b-4-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356636_M-34-63-B-b-4-4.asc
# ⬇️ Pobieram: 77532_1356646_M-34-63-D-b-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356646_M-34-63-D-b-2-2.asc
# ⬇️ Pobieram: 77532_1356650_M-34-64-A-a-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356650_M-34-64-A-a-2-2.asc
# ⬇️ Pobieram: 77532_1356641_M-34-63-B-d-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356641_M-34-63-B-d-3-4.asc
# ⬇️ Pobieram: 77532_1356649_M-34-64-A-a-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356649_M-34-64-A-a-2-1.asc
# ⬇️ Pobieram: 77532_1356682_M-34-64-A-c-4-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356682_M-34-64-A-c-4-4.asc
# ⬇️ Pobieram: 77532_1356657_M-34-64-A-b-2-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356657_M-34-64-A-b-2-3.asc
# ⬇️ Pobieram: 77532_1356643_M-34-63-B-d-4-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356643_M-34-63-B-d-4-2.asc
# ⬇️ Pobieram: 77532_1356663_M-34-64-A-b-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356663_M-34-64-A-b-4-1.asc
# ⬇️ Pobieram: 77532_1356684_M-34-64-A-d-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356684_M-34-64-A-d-1-2.asc
# ⬇️ Pobieram: 77532_1356629_M-34-63-B-b-2-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356629_M-34-63-B-b-2-3.asc
# ⬇️ Pobieram: 77532_1356671_M-34-64-A-c-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356671_M-34-64-A-c-2-1.asc
# ⬇️ Pobieram: 77532_1356677_M-34-64-A-c-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356677_M-34-64-A-c-3-3.asc
# ⬇️ Pobieram: 77532_1356659_M-34-64-A-b-3-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356659_M-34-64-A-b-3-1.asc
# ⬇️ Pobieram: 77532_1356686_M-34-64-A-d-1-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356686_M-34-64-A-d-1-4.asc
# ⬇️ Pobieram: 77532_1356654_M-34-64-A-b-1-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356654_M-34-64-A-b-1-4.asc
# ⬇️ Pobieram: 77532_1356664_M-34-64-A-b-4-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356664_M-34-64-A-b-4-2.asc
# ⬇️ Pobieram: 77532_1356653_M-34-64-A-b-1-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356653_M-34-64-A-b-1-3.asc
# ⬇️ Pobieram: 77532_1356693_M-34-64-A-d-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356693_M-34-64-A-d-3-3.asc
# ⬇️ Pobieram: 77532_1356564_M-34-64-C-a-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356564_M-34-64-C-a-2-2.asc
# ⬇️ Pobieram: 77532_1356634_M-34-63-B-b-4-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356634_M-34-63-B-b-4-2.asc
# ⬇️ Pobieram: 77532_1356701_M-34-64-B-a-1-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356701_M-34-64-B-a-1-3.asc
# ⬇️ Pobieram: 77532_1356675_M-34-64-A-c-3-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356675_M-34-64-A-c-3-1.asc
# ⬇️ Pobieram: 77532_1356666_M-34-64-A-b-4-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356666_M-34-64-A-b-4-4.asc
# ⬇️ Pobieram: 77532_1356673_M-34-64-A-c-2-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356673_M-34-64-A-c-2-3.asc
# ⬇️ Pobieram: 77532_1356635_M-34-63-B-b-4-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356635_M-34-63-B-b-4-3.asc
# ⬇️ Pobieram: 77532_1356688_M-34-64-A-d-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356688_M-34-64-A-d-2-2.asc
# ⬇️ Pobieram: 77532_1356670_M-34-64-A-c-1-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356670_M-34-64-A-c-1-4.asc
# ⬇️ Pobieram: 77532_1356685_M-34-64-A-d-1-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356685_M-34-64-A-d-1-3.asc
# ⬇️ Pobieram: 77532_1356561_M-34-64-C-a-1-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356561_M-34-64-C-a-1-3.asc
# ⬇️ Pobieram: 77532_1356648_M-34-64-A-a-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356648_M-34-64-A-a-1-1.asc
# ⬇️ Pobieram: 77532_1356642_M-34-63-B-d-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356642_M-34-63-B-d-4-1.asc
# ⬇️ Pobieram: 77532_1356703_M-34-64-B-a-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356703_M-34-64-B-a-2-1.asc
# ⬇️ Pobieram: 77532_1356640_M-34-63-B-d-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356640_M-34-63-B-d-3-3.asc
# ⬇️ Pobieram: 77532_1356700_M-34-64-B-a-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356700_M-34-64-B-a-1-2.asc
# ⬇️ Pobieram: 77532_1356683_M-34-64-A-d-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356683_M-34-64-A-d-1-1.asc
# ⬇️ Pobieram: 77532_1356639_M-34-63-B-d-2-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356639_M-34-63-B-d-2-4.asc
# ⬇️ Pobieram: 77532_1356658_M-34-64-A-b-2-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356658_M-34-64-A-b-2-4.asc
# ⬇️ Pobieram: 77532_1356672_M-34-64-A-c-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356672_M-34-64-A-c-2-2.asc
# ⬇️ Pobieram: 77532_1356630_M-34-63-B-b-2-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356630_M-34-63-B-b-2-4.asc
# ⬇️ Pobieram: 77532_1356655_M-34-64-A-b-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356655_M-34-64-A-b-2-1.asc
# ⬇️ Pobieram: 77532_1356660_M-34-64-A-b-3-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356660_M-34-64-A-b-3-2.asc
# ⬇️ Pobieram: 77532_1356674_M-34-64-A-c-2-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356674_M-34-64-A-c-2-4.asc
# ⬇️ Pobieram: 77532_1356638_M-34-63-B-d-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356638_M-34-63-B-d-2-2.asc
# ⬇️ Pobieram: 77532_1356679_M-34-64-A-c-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356679_M-34-64-A-c-4-1.asc
# ⬇️ Pobieram: 77532_1356707_M-34-64-B-a-3-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356707_M-34-64-B-a-3-1.asc
# ⬇️ Pobieram: 77532_1356656_M-34-64-A-b-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356656_M-34-64-A-b-2-2.asc
# ⬇️ Pobieram: 77532_1356691_M-34-64-A-d-3-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356691_M-34-64-A-d-3-1.asc
# ⬇️ Pobieram: 77536_1356792_M-34-75-B-b-3-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356792_M-34-75-B-b-3-1.asc
# ⬇️ Pobieram: 77520_1352828_M-34-76-A-b-1-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352828_M-34-76-A-b-1-3.asc
# ⬇️ Pobieram: 77520_1352784_M-34-64-C-d-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352784_M-34-64-C-d-3-4.asc
# ⬇️ Pobieram: 77536_1356878_M-34-76-A-d-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356878_M-34-76-A-d-2-1.asc
# ⬇️ Pobieram: 77520_1352821_M-34-76-A-a-1-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352821_M-34-76-A-a-1-4.asc
# ⬇️ Pobieram: 77520_1352822_M-34-76-A-a-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352822_M-34-76-A-a-2-1.asc
# ⬇️ Pobieram: 77536_1356851_M-34-76-A-a-4-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356851_M-34-76-A-a-4-3.asc
# ⬇️ Pobieram: 77520_1352824_M-34-76-A-a-2-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352824_M-34-76-A-a-2-3.asc
# ⬇️ Pobieram: 77536_1356789_M-34-75-B-a-4-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356789_M-34-75-B-a-4-2.asc
# ⬇️ Pobieram: 77520_1352769_M-34-64-C-c-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352769_M-34-64-C-c-4-1.asc
# ⬇️ Pobieram: 77536_1356786_M-34-75-B-a-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356786_M-34-75-B-a-3-3.asc
# ⬇️ Pobieram: 77536_1356906_M-34-76-B-c-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356906_M-34-76-B-c-1-1.asc
# ⬇️ Pobieram: 77520_1352799_M-34-75-A-b-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352799_M-34-75-A-b-2-2.asc
# ⬇️ Pobieram: 77536_1356801_M-34-75-B-c-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356801_M-34-75-B-c-1-2.asc
# ⬇️ Pobieram: 77536_1356847_M-34-76-A-a-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356847_M-34-76-A-a-3-3.asc
# ⬇️ Pobieram: 77536_1356854_M-34-76-A-b-3-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356854_M-34-76-A-b-3-2.asc
# ⬇️ Pobieram: 77536_1356892_M-34-76-B-a-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356892_M-34-76-B-a-3-3.asc
# ⬇️ Pobieram: 77536_1356846_M-34-76-A-a-3-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356846_M-34-76-A-a-3-2.asc
# ⬇️ Pobieram: 77536_1356788_M-34-75-B-a-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356788_M-34-75-B-a-4-1.asc
# ⬇️ Pobieram: 77536_1356864_M-34-76-A-c-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356864_M-34-76-A-c-2-2.asc
# ⬇️ Pobieram: 77536_1356816_M-34-75-B-d-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356816_M-34-75-B-d-2-1.asc
# ⬇️ Pobieram: 77536_1356849_M-34-76-A-a-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356849_M-34-76-A-a-4-1.asc
# ⬇️ Pobieram: 77536_1356784_M-34-75-B-a-3-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356784_M-34-75-B-a-3-1.asc
# ⬇️ Pobieram: 77520_1352731_M-34-63-D-d-2-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352731_M-34-63-D-d-2-3.asc
# ⬇️ Pobieram: 77520_1352745_M-34-64-C-a-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352745_M-34-64-C-a-4-1.asc
# ⬇️ Pobieram: 77536_1356787_M-34-75-B-a-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356787_M-34-75-B-a-3-4.asc
# ⬇️ Pobieram: 77520_1352737_M-34-63-D-d-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352737_M-34-63-D-d-4-1.asc
# ⬇️ Pobieram: 77536_1356855_M-34-76-A-b-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356855_M-34-76-A-b-3-3.asc
# ⬇️ Pobieram: 77520_1352729_M-34-63-D-d-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352729_M-34-63-D-d-2-1.asc
# ⬇️ Pobieram: 77536_1356800_M-34-75-B-c-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356800_M-34-75-B-c-1-1.asc
# ⬇️ Pobieram: 77520_1352722_M-34-63-D-c-4-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352722_M-34-63-D-c-4-2.asc
# ⬇️ Pobieram: 77536_1356879_M-34-76-A-d-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356879_M-34-76-A-d-2-2.asc
# ⬇️ Pobieram: 77520_1352809_M-34-75-B-a-2-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352809_M-34-75-B-a-2-4.asc
# ⬇️ Pobieram: 77520_1352803_M-34-75-B-a-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352803_M-34-75-B-a-1-2.asc
# ⬇️ Pobieram: 77520_1352811_M-34-75-B-b-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352811_M-34-75-B-b-1-2.asc
# ⬇️ Pobieram: 77536_1356804_M-34-75-B-c-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356804_M-34-75-B-c-2-1.asc
# ⬇️ Pobieram: 77520_1352815_M-34-75-B-b-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352815_M-34-75-B-b-2-2.asc
# ⬇️ Pobieram: 77520_1352710_M-34-63-D-a-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352710_M-34-63-D-a-4-1.asc
# ⬇️ Pobieram: 77520_1352765_M-34-64-C-c-3-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352765_M-34-64-C-c-3-1.asc
# ⬇️ Pobieram: 77520_1352712_M-34-63-D-b-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352712_M-34-63-D-b-3-4.asc
# ⬇️ Pobieram: 77520_1352719_M-34-63-D-c-2-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352719_M-34-63-D-c-2-2.asc
# ⬇️ Pobieram: 77520_1352711_M-34-63-D-a-4-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352711_M-34-63-D-a-4-3.asc
# ⬇️ Pobieram: 77536_1356861_M-34-76-A-c-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356861_M-34-76-A-c-1-2.asc
# ⬇️ Pobieram: 77520_1352743_M-34-64-C-a-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352743_M-34-64-C-a-3-3.asc
# ⬇️ Pobieram: 77536_1356791_M-34-75-B-a-4-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356791_M-34-75-B-a-4-4.asc
# ⬇️ Pobieram: 77520_1352806_M-34-75-B-a-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352806_M-34-75-B-a-2-1.asc
# ⬇️ Pobieram: 77520_1352761_M-34-64-C-c-2-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352761_M-34-64-C-c-2-1.asc
# ⬇️ Pobieram: 77536_1356857_M-34-76-A-b-4-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356857_M-34-76-A-b-4-1.asc
# ⬇️ Pobieram: 77536_1356856_M-34-76-A-b-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356856_M-34-76-A-b-3-4.asc
# ⬇️ Pobieram: 77520_1352827_M-34-76-A-b-1-2.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352827_M-34-76-A-b-1-2.asc
# ⬇️ Pobieram: 77520_1352768_M-34-64-C-c-3-4.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352768_M-34-64-C-c-3-4.asc
# ⬇️ Pobieram: 77520_1352826_M-34-76-A-b-1-1.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352826_M-34-76-A-b-1-1.asc
# ⬇️ Pobieram: 77520_1352721_M-34-63-D-c-3-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77520_1352721_M-34-63-D-c-3-3.asc
# ⬇️ Pobieram: 77536_1356790_M-34-75-B-a-4-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77536_1356790_M-34-75-B-a-4-3.asc
# ⬇️ Pobieram: 77532_1356565_M-34-64-C-a-2-3.asc
# ✅ Pobrano: E:\kafle_las\NMT\77532_1356565_M-34-64-C-a-2-3.asc
# ⬇️ Pobieram: 77520_1352766_M-34-64-C-c-3-2.asc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 for i, layer in dane_nmt.iterrows():
# ----> 2     pobierz_nmt_asc(layer['url_do_pobrania'], output_nmt)
#
# Cell In[19], line 18, in pobierz_nmt_asc(url, out_dir, overwrite, timeout)
#      15 r.raise_for_status()
#      17 with open(out_path, "wb") as f:
# ---> 18     for chunk in r.iter_content(chunk_size=1024 * 1024):
#      19         if chunk:
#      20             f.write(chunk)
#
# File ~\miniconda3\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~\miniconda3\Lib\site-packages\urllib3\response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091         data = self.read(amt=amt, decode_content=decode_content)
#    1093         if data:
#    1094             yield data
#
# File ~\miniconda3\Lib\site-packages\urllib3\response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     977     if len(self._decoded_buffer) >= amt:
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#     984 if not data and len(self._decoded_buffer) == 0:
#
# File ~\miniconda3\Lib\site-packages\urllib3\response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)    912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#     914         self._fp.close()
#
# File ~\miniconda3\Lib\site-packages\urllib3\response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     884     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\miniconda3\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~\miniconda3\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\miniconda3\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\miniconda3\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
len(dane_nmt)
# Out:
# 4283
